# %% [markdown]
# # Arrests Data

# %%
# imports
import pandas as pd
file = pd.read_csv("arrests.csv")
file
# Out:
#          _id              Template   Case_Number  \
# 0          1  Adult Arrest-On View  PGHP25000026
# 1          2  Adult Arrest-On View  PGHP25000110
# 2          3  Adult Arrest-On View  PGHP25000110
# 3          4  Adult Arrest-On View  PGHP25000110
# 4          5  Adult Arrest-On View  PGHP25000110
# ...      ...                   ...           ...
# 22022  22023  Adult Arrest-On View  PGHP24193437
# 22023  22024  Adult Arrest-On View  PGHP24193437
# 22024  22025  Adult Arrest-On View  PGHP24193437
# 22025  22026  Adult Arrest-On View  PGHP24193437
# 22026  22027  Adult Arrest-On View  PGHP24193437
#
#                             ArrestPerson_ID          Arrest_Date  Arrest_Year  \
# 0      b09e1066-c355-cc1b-218c-08dd2a4354ea  2025-01-01T00:00:00       2025.0
# 1      e97f5c84-ddf3-c039-b576-08dd2a41a058  2025-01-01T00:00:00       2025.0
# 2      e97f5c84-ddf3-c039-b576-08dd2a41a058  2025-01-01T00:00:00       2025.0
# 3      e97f5c84-ddf3-c039-b576-08dd2a41a058  2025-01-01T00:00:00       2025.0
# 4      e97f5c84-ddf3-c039-b576-08dd2a41a058  2025-01-01T00:00:00       2025.0
# ...                                     ...                  ...          ...
# 22022  f938e6a6-448c-c84d-e72e-08dd2a17f8d5  2024-12-31T00:00:00       2024.0
# 22023  12f028a9-5faf-cc84-645c-08dd2a19ed62  2024-12-31T00:00:00       2024.0
# 22024  12f028a9-5faf-cc84-645c-08dd2a19ed62  2024-12-31T00:00:00       2024.0
# 22025  12f028a9-5faf-cc84-645c-08dd2a19ed62  2024-12-31T00:00:00       2024.0
# 22026  12f028a9-5faf-cc84-645c-08dd2a19ed62  2024-12-31T00:00:00       2024.0
#
#       Arrest_Month Arrest_Time  \
# 0              Jan       04:04
# 1              Jan       03:52
# 2              Jan       03:52
# 3              Jan       03:52
# 4              Jan       03:52
# ...            ...         ...
# 22022          Dec       22:54
# 22023          Dec       23:08
# 22024          Dec       23:08
# 22025          Dec       23:08
# 22026          Dec       23:08
#
#                                                     Type  ArrestPerson_Age  \
# 0      On-View Arrest (apprehension without a warrant...              21.0
# 1      On-View Arrest (apprehension without a warrant...              23.0
# 2      On-View Arrest (apprehension without a warrant...              23.0
# 3      On-View Arrest (apprehension without a warrant...              23.0
# 4      On-View Arrest (apprehension without a warrant...              23.0
# ...                                                  ...               ...
# 22022  On-View Arrest (apprehension without a warrant...              21.0
# 22023  On-View Arrest (apprehension without a warrant...              44.0
# 22024  On-View Arrest (apprehension without a warrant...              44.0
# 22025  On-View Arrest (apprehension without a warrant...              44.0
# 22026  On-View Arrest (apprehension without a warrant...              44.0
#
#        ...           NIBRS_Crime_Against NIBRS_Offense_Grouping  \
# 0      ...                       Society                      B
# 1      ...                       Society                      A
# 2      ...  Person, Property, or Society                      B
# 3      ...  Person, Property, or Society                      B
# 4      ...  Person, Property, or Society                      B
# ...    ...                           ...                    ...
# 22022  ...                        Person                      A
# 22023  ...                       Society                      B
# 22024  ...                       Society                      B
# 22025  ...                        Person                      A
# 22026  ...                        Person                      A
#
#                                                Violation    Zone   Tract  \
# 0      18 5503 A1* Disorderly Conduct-Fighting/Threat...  Zone 3  1702.0
# 1      18 6106 A1 Firearms Act-Carrying Firearm W/O L...  Zone 3  1702.0
# 2      75 3353 A2II Illegal Park W/I 15 Feet of Fire ...  Zone 3  1702.0
# 3      75 3353 A3II Illegal Park Where Official Signs...  Zone 3  1702.0
# 4             75 3353 A1III Illegal Park In Intersection  Zone 3  1702.0
# ...                                                  ...     ...     ...
# 22022  18 2702 A3 Aggravated Assault-Injury To Police...  Zone 3  2904.0
# 22023  18 5503 A1 Disorderly Conduct-Fighting/Threate...  Zone 3  2904.0
# 22024                         18 5505 Public Drunkenness  Zone 3  2904.0
# 22025  18 2702 A3 Aggravated Assault-Injury To Police...  Zone 3  2904.0
# 22026                           18 5104 Resisting Arrest  Zone 3  2904.0
#
#            Neighborhood ArrestCharge_Felony_Misdemeanor_Description   XCOORD  \
# 0      South Side Flats                            MISDEMEANOR - M3 -79.9824
# 1      South Side Flats                                 FELONY - F3 -79.9820
# 2      South Side Flats                              INFRACTION - S -79.9820
# 3      South Side Flats                              INFRACTION - S -79.9820
# 4      South Side Flats                              INFRACTION - S -79.9820
# ...                 ...                                         ...      ...
# 22022           Carrick                                 FELONY - F2 -79.9812
# 22023           Carrick                              INFRACTION - S -79.9812
# 22024           Carrick                              INFRACTION - S -79.9812
# 22025           Carrick                                 FELONY - F2 -79.9812
# 22026           Carrick                            MISDEMEANOR - M2 -79.9812
#
#         YCOORD                                      Block_Address
# 0      40.4288      1600 Block of  E Carson Street Pittsburgh, PA
# 1      40.4298  Intersection of SIDNEY ST./ S. 17TH ST. Pittsb...
# 2      40.4298  Intersection of SIDNEY ST./ S. 17TH ST. Pittsb...
# 3      40.4298  Intersection of SIDNEY ST./ S. 17TH ST. Pittsb...
# 4      40.4298  Intersection of SIDNEY ST./ S. 17TH ST. Pittsb...
# ...        ...                                                ...
# 22022  40.3860           2500 Block of  Edgar St.  Pittsburgh, PA
# 22023  40.3860            2500 Block of  Edgar St. Pittsburgh, PA
# 22024  40.3860            2500 Block of  Edgar St. Pittsburgh, PA
# 22025  40.3860            2500 Block of  Edgar St. Pittsburgh, PA
# 22026  40.3860            2500 Block of  Edgar St. Pittsburgh, PA
#
# [22027 rows x 26 columns]

# %% [markdown]
# # Bar Graph of Neighborhoods with the Fewest Arrests

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

data = pd.read_csv("arrests.csv")
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

data = pd.read_csv("arrests.csv")

arrests_per_neighborhood = data['Neighborhood'].value_counts()

# Sort the series in ascending order and get the first 20 (lowest)
bottom_20_neighborhoods = arrests_per_neighborhood.sort_values().head(20)

# Display the neighborhoods with the lowest number of arrests

# Create a bar graph
plt.figure(figsize=(20, 10))
sns.barplot(x=bottom_20_neighborhoods.values, y=bottom_20_neighborhoods.index, palette='viridis')
plt.title('Neighborhoods with the Fewest Arrests')
plt.xlabel('Number of Arrests')
plt.ylabel('Neighborhood')
plt.show()

# %%
# !pip install tabulate
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: tabulate in /ihome/cs1671_2025s/dam318/.local/lib/python3.11/site-packages (0.9.0)

# %%
import pandas as pd
from tabulate import tabulate

# Load the arrests dataset
arrests_data = pd.read_csv("arrests.csv")

# Group by neighborhood and count the number of arrests
arrests_per_neighborhood = arrests_data['Neighborhood'].value_counts().reset_index()
arrests_per_neighborhood.columns = ['Neighborhood', 'Total Arrests']

# Sort by Total Arrests in ascending order
arrests_per_neighborhood = arrests_per_neighborhood.sort_values(by='Total Arrests', ascending=True)

# Display the 20 neighborhoods with the least arrests
print(tabulate(arrests_per_neighborhood.head(20), headers='keys', tablefmt='fancy_grid'))
# Out:
# ╒════╤═════════════════════╤═════════════════╕
# │    │ Neighborhood        │   Total Arrests │
# ╞════╪═════════════════════╪═════════════════╡
# │ 90 │ Swisshelm Park      │               8 │
# ├────┼─────────────────────┼─────────────────┤
# │ 89 │ Ridgemont           │               9 │
# ├────┼─────────────────────┼─────────────────┤
# │ 88 │ Chartiers           │              11 │
# ├────┼─────────────────────┼─────────────────┤
# │ 87 │ Saint Clair         │              12 │
# ├────┼─────────────────────┼─────────────────┤
# │ 86 │ Regent Square       │              12 │
# ├────┼─────────────────────┼─────────────────┤
# │ 85 │ Mount Oliver        │              17 │
# ├────┼─────────────────────┼─────────────────┤
# │ 84 │ Summer Hill         │              17 │
# ├────┼─────────────────────┼─────────────────┤
# │ 83 │ New Homestead       │              18 │
# ├────┼─────────────────────┼─────────────────┤
# │ 82 │ Oakwood             │              22 │
# ├────┼─────────────────────┼─────────────────┤
# │ 81 │ Glen Hazel          │              22 │
# ├────┼─────────────────────┼─────────────────┤
# │ 78 │ East Carnegie       │              23 │
# ├────┼─────────────────────┼─────────────────┤
# │ 79 │ Morningside         │              23 │
# ├────┼─────────────────────┼─────────────────┤
# │ 80 │ Esplen              │              23 │
# ├────┼─────────────────────┼─────────────────┤
# │ 77 │ Fairywood           │              29 │
# ├────┼─────────────────────┼─────────────────┤
# │ 76 │ Upper Hill          │              31 │
# ├────┼─────────────────────┼─────────────────┤
# │ 75 │ Hays                │              33 │
# ├────┼─────────────────────┼─────────────────┤
# │ 74 │ Friendship          │              37 │
# ├────┼─────────────────────┼─────────────────┤
# │ 73 │ Upper Lawrenceville │              40 │
# ├────┼─────────────────────┼─────────────────┤
# │ 72 │ Lower Lawrenceville │              40 │
# ├────┼─────────────────────┼─────────────────┤
# │ 71 │ Spring Garden       │              41 │
# ╘════╧═════════════════════╧═════════════════╛

# %% [markdown]
# # ANALYSIS

# %% [markdown]
# The neighborhoods with the **lowest arrest totals** are **Swisshelm Park** (8 arrests), **Ridgemont** (9), and **Chartiers** (11), suggesting these areas may be among the safest in Pittsburgh. Others like **Saint Clair** and **Regent Square** (both with 12 arrests) also rank very low. These low numbers may reflect strong community safety, less crime, or limited police activity in those neighborhoods.

# %%
import pandas as pd

# Load the arrests dataset
arrests_data = pd.read_csv("arrests.csv")

# Count total arrests per neighborhood (case-insensitive column fix)
arrests_grouped = arrests_data.groupby('Neighborhood', as_index=False).size()
arrests_grouped.columns = ['neighborhood', 'total_arrests']

# Score: lower arrests = higher safety score
arrests_grouped['safety_score'] = 1 - (arrests_grouped['total_arrests'] / arrests_grouped['total_arrests'].max())

# Preview safest neighborhoods
print(arrests_grouped.sort_values(by='safety_score', ascending=False).head())
# Out:
#       neighborhood  total_arrests  safety_score
# 82  Swisshelm Park              8      0.997117
# 67       Ridgemont              9      0.996757
# 20       Chartiers             11      0.996036
# 66   Regent Square             12      0.995676
# 68     Saint Clair             12      0.995676
